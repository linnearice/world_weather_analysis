# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats =  np.random.uniform(low=-90.000, high= 90.000,size=2000)
lngs = np.random.uniform(low=-180.000, high= 180.000,size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
coordinates=list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and logitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Import the datetime module from the datetime library
from datetime import datetime

# %%
# Import the requests library
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create and empty list to hold the weather data.
city_data=[]
# Print the beginning of the logging.
print("Beginning Data Retrieval      ")
print("------------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ------------------------------

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count += 1
    # Create endpoint url with each city.
    city_url=url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record{record_count} of Set {set_count} | {city}")
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record1 of Set 1 | fangshan
# Processing Record2 of Set 1 | obigarm
# Processing Record3 of Set 1 | hobart
# Processing Record4 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record5 of Set 1 | saskylakh
# Processing Record6 of Set 1 | port-gentil
# Processing Record7 of Set 1 | butaritari
# Processing Record8 of Set 1 | bubaque
# Processing Record9 of Set 1 | asau
# Processing Record10 of Set 1 | ouango
# Processing Record11 of Set 1 | ribeira grande
# Processing Record12 of Set 1 | avarua
# Processing Record13 of Set 1 | castro
# Processing Record14 of Set 1 | stornoway
# Processing Record15 of Set 1 | kruisfontein
# Processing Record16 of Set 1 | ushuaia
# Processing Record17 of Set 1 | chokurdakh
# Processing Record18 of Set 1 | mataura
# Processing Record19 of Set 1 | binzhou
# Processing Record20 of Set 1 | fortuna
# Processing Record21 of Set 1 | baglan
# Processing Record22 of Set 1 | chingola
# Processing Record23 of Set 1 | albany
# Processing Record24 of Set 1 | lorengau
# Processing Record25 of Set 1 | doha
# Processing Record26 of Set 1 | camacha
# Processing Record27 of Set 1 | kapaa
# Processing Record28 of Set 1 | kenora
# Processing Record29 of Set 1 | leningradskiy
# Processing Record30 of Set 1 | amderma
# City not found. Skipping...
# Processing Record31 of Set 1 | north bend
# Processing Record32 of Set 1 | atuona
# Processing Record33 of Set 1 | brae
# Processing Record34 of Set 1 | busselton
# Processing Record35 of Set 1 | khatanga
# Processing Record36 of Set 1 | plettenberg bay
# Processing Record37 of Set 1 | bengkulu
# Processing Record38 of Set 1 | marsa matruh
# Processing Record39 of Set 1 | klaksvik
# Processing Record40 of Set 1 | hithadhoo
# Processing Record41 of Set 1 | punta arenas
# Processing Record42 of Set 1 | bluff
# Processing Record43 of Set 1 | saverne
# Processing Record44 of Set 1 | cape town
# Processing Record45 of Set 1 | bengkalis
# City not found. Skipping...
# Processing Record46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record47 of Set 1 | saint-philippe
# Processing Record48 of Set 1 | ilulissat
# Processing Record49 of Set 1 | boa vista
# Processing Record50 of Set 1 | santa isabel do rio negro
# Processing Record52 of Set 2 | chuy
# Processing Record53 of Set 2 | komsomolets
# Processing Record54 of Set 2 | bredasdorp
# Processing Record55 of Set 2 | cabo san lucas
# Processing Record56 of Set 2 | waris aliganj
# Processing Record57 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record58 of Set 2 | nanortalik
# Processing Record59 of Set 2 | namatanai
# Processing Record60 of Set 2 | namibe
# Processing Record61 of Set 2 | port alfred
# Processing Record62 of Set 2 | esperance
# Processing Record63 of Set 2 | hasaki
# Processing Record64 of Set 2 | los andes
# Processing Record65 of Set 2 | ovalle
# Processing Record66 of Set 2 | vanavara
# Processing Record67 of Set 2 | vaini
# Processing Record68 of Set 2 | kavieng
# Processing Record69 of Set 2 | ust-nera
# Processing Record70 of Set 2 | yingkou
# Processing Record71 of Set 2 | powell river
# Processing Record72 of Set 2 | rikitea
# Processing Record73 of Set 2 | mount isa
# Processing Record74 of Set 2 | sabang
# Processing Record75 of Set 2 | tuktoyaktuk
# Processing Record76 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record77 of Set 2 | hilo
# Processing Record78 of Set 2 | chichi
# Processing Record79 of Set 2 | adet
# Processing Record80 of Set 2 | brumado
# Processing Record81 of Set 2 | tiznit
# Processing Record82 of Set 2 | palana
# Processing Record83 of Set 2 | upernavik
# Processing Record84 of Set 2 | bijie
# Processing Record85 of Set 2 | hamilton
# Processing Record86 of Set 2 | thompson
# Processing Record87 of Set 2 | geraldton
# Processing Record88 of Set 2 | tucurui
# Processing Record89 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record90 of Set 2 | naze
# Processing Record91 of Set 2 | cayenne
# Processing Record92 of Set 2 | nikolskoye
# Processing Record93 of Set 2 | palmas
# Processing Record94 of Set 2 | rawson
# Processing Record95 of Set 2 | beterou
# Processing Record96 of Set 2 | hermanus
# Processing Record97 of Set 2 | yellowknife
# Processing Record98 of Set 2 | guerrero negro
# Processing Record99 of Set 2 | puerto ayora
# Processing Record100 of Set 2 | grand gaube
# Processing Record101 of Set 2 | maniitsoq
# Processing Record103 of Set 3 | qaanaaq
# Processing Record104 of Set 3 | kununurra
# Processing Record105 of Set 3 | provideniya
# Processing Record106 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record107 of Set 3 | new norfolk
# Processing Record108 of Set 3 | norden
# Processing Record109 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record110 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record111 of Set 3 | ugoofaaru
# Processing Record112 of Set 3 | valparaiso
# Processing Record113 of Set 3 | carnarvon
# Processing Record114 of Set 3 | tokur
# Processing Record115 of Set 3 | el cobre
# Processing Record116 of Set 3 | corowa
# Processing Record117 of Set 3 | saldanha
# Processing Record118 of Set 3 | port elizabeth
# Processing Record119 of Set 3 | katsuura
# Processing Record120 of Set 3 | pingliang
# Processing Record121 of Set 3 | samusu
# City not found. Skipping...
# Processing Record122 of Set 3 | shache
# Processing Record123 of Set 3 | port hardy
# Processing Record124 of Set 3 | chapayeve
# Processing Record125 of Set 3 | totskoye
# Processing Record126 of Set 3 | olafsvik
# Processing Record127 of Set 3 | tanout
# Processing Record128 of Set 3 | redmond
# Processing Record129 of Set 3 | dandong
# Processing Record130 of Set 3 | arraial do cabo
# Processing Record131 of Set 3 | brazzaville
# Processing Record132 of Set 3 | cherskiy
# Processing Record133 of Set 3 | aljezur
# Processing Record134 of Set 3 | bethel
# Processing Record135 of Set 3 | burnie
# Processing Record136 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record137 of Set 3 | hualmay
# Processing Record138 of Set 3 | sterling
# Processing Record139 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record140 of Set 3 | versalles
# Processing Record141 of Set 3 | hami
# Processing Record142 of Set 3 | luanda
# Processing Record143 of Set 3 | mahebourg
# Processing Record144 of Set 3 | inuvik
# Processing Record145 of Set 3 | serowe
# Processing Record146 of Set 3 | axim
# Processing Record147 of Set 3 | panino
# Processing Record148 of Set 3 | norman wells
# Processing Record149 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record150 of Set 3 | souillac
# Processing Record151 of Set 3 | assiniboia
# Processing Record152 of Set 3 | tir pol
# City not found. Skipping...
# Processing Record154 of Set 4 | linguere
# Processing Record155 of Set 4 | bambous virieux
# Processing Record156 of Set 4 | pacific grove
# Processing Record157 of Set 4 | barrow
# Processing Record158 of Set 4 | maine-soroa
# Processing Record159 of Set 4 | faya
# Processing Record160 of Set 4 | kodiak
# Processing Record161 of Set 4 | hervey bay
# Processing Record162 of Set 4 | tessalit
# Processing Record163 of Set 4 | madimba
# Processing Record164 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record165 of Set 4 | tukrah
# Processing Record166 of Set 4 | kutum
# Processing Record167 of Set 4 | florianopolis
# Processing Record168 of Set 4 | castrillon
# Processing Record169 of Set 4 | barra patuca
# Processing Record170 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record171 of Set 4 | lasa
# Processing Record172 of Set 4 | lancaster
# Processing Record173 of Set 4 | saanen
# Processing Record174 of Set 4 | mersin
# Processing Record175 of Set 4 | vanimo
# Processing Record176 of Set 4 | fort portal
# Processing Record177 of Set 4 | nome
# Processing Record178 of Set 4 | kavaratti
# Processing Record179 of Set 4 | bassar
# Processing Record180 of Set 4 | senanga
# Processing Record181 of Set 4 | mount gambier
# Processing Record182 of Set 4 | lebu
# Processing Record183 of Set 4 | panacan
# Processing Record184 of Set 4 | kulhudhuffushi
# Processing Record185 of Set 4 | sitka
# Processing Record186 of Set 4 | almeria
# Processing Record187 of Set 4 | rehoboth
# Processing Record188 of Set 4 | morro bay
# Processing Record189 of Set 4 | tasiilaq
# Processing Record190 of Set 4 | diamantino
# Processing Record191 of Set 4 | port lincoln
# Processing Record192 of Set 4 | troy
# Processing Record193 of Set 4 | dekoa
# City not found. Skipping...
# Processing Record194 of Set 4 | tiksi
# Processing Record195 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record196 of Set 4 | airai
# Processing Record197 of Set 4 | erenhot
# Processing Record198 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record199 of Set 4 | santa rosa del sur
# Processing Record200 of Set 4 | suifenhe
# Processing Record201 of Set 4 | andijon
# Processing Record202 of Set 4 | zhigansk
# Processing Record203 of Set 4 | hudiksvall
# Processing Record205 of Set 5 | ndjole
# Processing Record206 of Set 5 | loukhi
# Processing Record207 of Set 5 | puerto ayacucho
# Processing Record208 of Set 5 | caravelas
# Processing Record209 of Set 5 | saint george
# Processing Record210 of Set 5 | ondjiva
# Processing Record211 of Set 5 | zaoyang
# Processing Record212 of Set 5 | sahuaripa
# Processing Record213 of Set 5 | miyako
# Processing Record214 of Set 5 | ponta delgada
# Processing Record215 of Set 5 | tam ky
# Processing Record216 of Set 5 | egvekinot
# Processing Record217 of Set 5 | sao jose da coroa grande
# Processing Record218 of Set 5 | khandyga
# Processing Record219 of Set 5 | caico
# Processing Record220 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record221 of Set 5 | kangaatsiaq
# Processing Record222 of Set 5 | thinadhoo
# Processing Record223 of Set 5 | jamestown
# Processing Record224 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record225 of Set 5 | cockburn town
# Processing Record226 of Set 5 | luba
# Processing Record227 of Set 5 | vardo
# Processing Record228 of Set 5 | aklavik
# Processing Record229 of Set 5 | huarmey
# Processing Record230 of Set 5 | martin
# Processing Record231 of Set 5 | hofn
# Processing Record232 of Set 5 | puerto escondido
# Processing Record233 of Set 5 | edd
# Processing Record234 of Set 5 | byron bay
# Processing Record235 of Set 5 | trat
# Processing Record236 of Set 5 | maceio
# Processing Record237 of Set 5 | narsaq
# Processing Record238 of Set 5 | east london
# Processing Record239 of Set 5 | kalabo
# Processing Record240 of Set 5 | galveston
# Processing Record241 of Set 5 | walvis bay
# Processing Record242 of Set 5 | phalodi
# Processing Record243 of Set 5 | san cristobal
# Processing Record244 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record245 of Set 5 | odweyne
# Processing Record246 of Set 5 | balabac
# Processing Record247 of Set 5 | codrington
# Processing Record248 of Set 5 | batemans bay
# Processing Record249 of Set 5 | george town
# Processing Record250 of Set 5 | tautira
# Processing Record251 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record252 of Set 5 | grindavik
# Processing Record253 of Set 5 | uberaba
# Processing Record254 of Set 5 | sao filipe
# Processing Record256 of Set 6 | mitu
# Processing Record257 of Set 6 | ostrovnoy
# Processing Record258 of Set 6 | vila velha
# Processing Record259 of Set 6 | karratha
# Processing Record260 of Set 6 | nurobod
# Processing Record261 of Set 6 | haileybury
# Processing Record262 of Set 6 | seryshevo
# Processing Record263 of Set 6 | yeppoon
# Processing Record264 of Set 6 | luena
# Processing Record265 of Set 6 | manchar
# Processing Record266 of Set 6 | damara
# Processing Record267 of Set 6 | miri
# Processing Record268 of Set 6 | arkhangelsk
# Processing Record269 of Set 6 | tazovskiy
# Processing Record270 of Set 6 | auburn hills
# Processing Record271 of Set 6 | changji
# Processing Record272 of Set 6 | salalah
# Processing Record273 of Set 6 | sabalgarh
# Processing Record274 of Set 6 | bazarnyye mataki
# Processing Record275 of Set 6 | alice springs
# Processing Record276 of Set 6 | buala
# Processing Record277 of Set 6 | qasigiannguit
# Processing Record278 of Set 6 | avera
# Processing Record279 of Set 6 | conde
# Processing Record280 of Set 6 | georgetown
# Processing Record281 of Set 6 | mitsamiouli
# Processing Record282 of Set 6 | anqing
# Processing Record283 of Set 6 | peruibe
# Processing Record284 of Set 6 | hede
# Processing Record285 of Set 6 | iznik
# Processing Record286 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record287 of Set 6 | portland
# Processing Record288 of Set 6 | cidreira
# Processing Record289 of Set 6 | mar del plata
# Processing Record290 of Set 6 | rolla
# Processing Record291 of Set 6 | pangody
# Processing Record292 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record293 of Set 6 | nouadhibou
# Processing Record294 of Set 6 | vestmannaeyjar
# Processing Record295 of Set 6 | linxia
# Processing Record296 of Set 6 | meulaboh
# Processing Record297 of Set 6 | panuco
# Processing Record298 of Set 6 | saint-augustin
# Processing Record299 of Set 6 | salinopolis
# Processing Record300 of Set 6 | khromtau
# Processing Record301 of Set 6 | pacifica
# Processing Record302 of Set 6 | sinnamary
# Processing Record303 of Set 6 | natal
# Processing Record304 of Set 6 | fairbanks
# Processing Record305 of Set 6 | hefei
# Processing Record307 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record308 of Set 7 | ibra
# Processing Record309 of Set 7 | shelburne
# Processing Record310 of Set 7 | gat
# Processing Record311 of Set 7 | ahvaz
# Processing Record312 of Set 7 | yar-sale
# Processing Record313 of Set 7 | cabanas
# Processing Record314 of Set 7 | honiara
# Processing Record315 of Set 7 | mirnyy
# Processing Record316 of Set 7 | griffith
# Processing Record317 of Set 7 | berdyuzhye
# City not found. Skipping...
# Processing Record318 of Set 7 | marienburg
# Processing Record319 of Set 7 | komsomolskiy
# Processing Record320 of Set 7 | swift current
# Processing Record321 of Set 7 | longyearbyen
# Processing Record322 of Set 7 | kahului
# Processing Record323 of Set 7 | luwuk
# Processing Record324 of Set 7 | nakamura
# Processing Record325 of Set 7 | poopo
# Processing Record326 of Set 7 | emet
# Processing Record327 of Set 7 | porto novo
# Processing Record328 of Set 7 | cauquenes
# Processing Record329 of Set 7 | chicama
# Processing Record330 of Set 7 | dingle
# Processing Record331 of Set 7 | kayes
# Processing Record332 of Set 7 | padang
# Processing Record333 of Set 7 | anadyr
# Processing Record334 of Set 7 | shanghai
# Processing Record335 of Set 7 | ambon
# Processing Record336 of Set 7 | kudahuvadhoo
# Processing Record337 of Set 7 | barranca
# Processing Record338 of Set 7 | darab
# Processing Record339 of Set 7 | mykolayivka
# Processing Record340 of Set 7 | williston
# Processing Record341 of Set 7 | peniche
# Processing Record342 of Set 7 | zadar
# Processing Record343 of Set 7 | mersing
# Processing Record344 of Set 7 | talcahuano
# Processing Record345 of Set 7 | takoradi
# Processing Record346 of Set 7 | cajnice
# Processing Record347 of Set 7 | praia da vitoria
# Processing Record348 of Set 7 | muzhi
# Processing Record349 of Set 7 | kaitangata
# Processing Record350 of Set 7 | margate
# Processing Record351 of Set 7 | unity
# Processing Record352 of Set 7 | dalvik
# Processing Record353 of Set 7 | promyshlennovskiy
# Processing Record354 of Set 7 | icanti
# City not found. Skipping...
# Processing Record355 of Set 7 | pacasmayo
# Processing Record356 of Set 7 | piacabucu
# Processing Record358 of Set 8 | lodwar
# Processing Record359 of Set 8 | faanui
# Processing Record360 of Set 8 | najran
# Processing Record361 of Set 8 | vavuniya
# Processing Record362 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record363 of Set 8 | flin flon
# Processing Record364 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record365 of Set 8 | palauig
# Processing Record366 of Set 8 | itarema
# Processing Record367 of Set 8 | adrar
# Processing Record368 of Set 8 | grafton
# Processing Record369 of Set 8 | san patricio
# Processing Record370 of Set 8 | moose factory
# Processing Record371 of Set 8 | tripoli
# Processing Record372 of Set 8 | lompoc
# Processing Record373 of Set 8 | benjamin constant
# Processing Record374 of Set 8 | sataua
# City not found. Skipping...
# Processing Record375 of Set 8 | mentok
# City not found. Skipping...
# Processing Record376 of Set 8 | coihaique
# Processing Record377 of Set 8 | bilma
# Processing Record378 of Set 8 | yulara
# Processing Record379 of Set 8 | timmins
# Processing Record380 of Set 8 | dikson
# Processing Record381 of Set 8 | la ronge
# Processing Record382 of Set 8 | san quintin
# Processing Record383 of Set 8 | devils lake
# Processing Record384 of Set 8 | algonquin
# Processing Record385 of Set 8 | pangnirtung
# Processing Record386 of Set 8 | mehamn
# Processing Record387 of Set 8 | almazar
# Processing Record388 of Set 8 | bell ville
# Processing Record389 of Set 8 | vostok
# Processing Record390 of Set 8 | puerto baquerizo moreno
# Processing Record391 of Set 8 | roma
# Processing Record392 of Set 8 | kamaishi
# Processing Record393 of Set 8 | lukiv
# Processing Record394 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record395 of Set 8 | gimli
# Processing Record396 of Set 8 | cairns
# Processing Record397 of Set 8 | fuyu
# Processing Record398 of Set 8 | pasighat
# Processing Record399 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record400 of Set 8 | westport
# Processing Record401 of Set 8 | peterhead
# Processing Record402 of Set 8 | nyurba
# Processing Record403 of Set 8 | iqaluit
# Processing Record404 of Set 8 | college
# Processing Record405 of Set 8 | nuuk
# Processing Record406 of Set 8 | kashi
# Processing Record407 of Set 8 | kuala terengganu
# Processing Record409 of Set 9 | mosquera
# Processing Record410 of Set 9 | trinidad
# Processing Record411 of Set 9 | tulum
# Processing Record412 of Set 9 | riyadh
# Processing Record413 of Set 9 | socorro
# Processing Record414 of Set 9 | tura
# Processing Record415 of Set 9 | yanaul
# Processing Record416 of Set 9 | reconquista
# Processing Record417 of Set 9 | igrim
# Processing Record418 of Set 9 | muros
# Processing Record419 of Set 9 | torbay
# Processing Record420 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record421 of Set 9 | nouakchott
# Processing Record422 of Set 9 | lethem
# Processing Record423 of Set 9 | sao felix do xingu
# Processing Record424 of Set 9 | yarmouth
# Processing Record425 of Set 9 | zhicheng
# Processing Record426 of Set 9 | atambua
# Processing Record427 of Set 9 | touros
# Processing Record428 of Set 9 | marsh harbour
# Processing Record429 of Set 9 | brits
# Processing Record430 of Set 9 | tuatapere
# Processing Record431 of Set 9 | maarianhamina
# Processing Record432 of Set 9 | coquimbo
# Processing Record433 of Set 9 | mazyr
# Processing Record434 of Set 9 | bathsheba
# Processing Record435 of Set 9 | clyde river
# Processing Record436 of Set 9 | arman
# Processing Record437 of Set 9 | general roca
# Processing Record438 of Set 9 | naugarzan
# City not found. Skipping...
# Processing Record439 of Set 9 | sicamous
# Processing Record440 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record441 of Set 9 | sweetwater
# Processing Record442 of Set 9 | richards bay
# Processing Record443 of Set 9 | spornoye
# Processing Record444 of Set 9 | laurel
# Processing Record445 of Set 9 | gorontalo
# Processing Record446 of Set 9 | sarangani
# Processing Record447 of Set 9 | manavalakurichi
# Processing Record448 of Set 9 | vila franca do campo
# Processing Record449 of Set 9 | cap-aux-meules
# Processing Record450 of Set 9 | lebane
# Processing Record451 of Set 9 | astana
# Processing Record452 of Set 9 | pathein
# Processing Record453 of Set 9 | phitsanulok
# Processing Record454 of Set 9 | kailua
# Processing Record455 of Set 9 | buchanan
# Processing Record456 of Set 9 | lima
# Processing Record457 of Set 9 | sindor
# Processing Record458 of Set 9 | cornereva
# Processing Record460 of Set 10 | bernburg
# Processing Record461 of Set 10 | lokosovo
# Processing Record462 of Set 10 | illapel
# Processing Record463 of Set 10 | konevo
# Processing Record464 of Set 10 | cibitung
# Processing Record465 of Set 10 | ponta do sol
# Processing Record466 of Set 10 | ipatovo
# Processing Record467 of Set 10 | maragogi
# Processing Record468 of Set 10 | remanso
# Processing Record469 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record470 of Set 10 | nangomba
# Processing Record471 of Set 10 | lubango
# Processing Record472 of Set 10 | calafell
# Processing Record473 of Set 10 | katherine
# Processing Record474 of Set 10 | yaring
# Processing Record475 of Set 10 | dum duma
# Processing Record476 of Set 10 | stromness
# Processing Record477 of Set 10 | nishihara
# Processing Record478 of Set 10 | xining
# Processing Record479 of Set 10 | waipawa
# Processing Record480 of Set 10 | hanko
# Processing Record481 of Set 10 | mana
# Processing Record482 of Set 10 | broken hill
# Processing Record483 of Set 10 | tilichiki
# Processing Record484 of Set 10 | santiago
# Processing Record485 of Set 10 | roebourne
# Processing Record486 of Set 10 | pandan
# Processing Record487 of Set 10 | talnakh
# Processing Record488 of Set 10 | constitucion
# Processing Record489 of Set 10 | nizhniy kuranakh
# Processing Record490 of Set 10 | ust-ilimsk
# Processing Record491 of Set 10 | san nicolas
# Processing Record492 of Set 10 | jizan
# Processing Record493 of Set 10 | bafoulabe
# Processing Record494 of Set 10 | kisangani
# Processing Record495 of Set 10 | evensk
# Processing Record496 of Set 10 | seoul
# Processing Record497 of Set 10 | levelland
# Processing Record498 of Set 10 | kilindoni
# Processing Record499 of Set 10 | turbat
# Processing Record500 of Set 10 | severo-kurilsk
# Processing Record501 of Set 10 | rio grande
# Processing Record502 of Set 10 | boyolangu
# Processing Record503 of Set 10 | bay roberts
# Processing Record504 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record505 of Set 10 | luangwa
# Processing Record506 of Set 10 | kyra
# Processing Record507 of Set 10 | batagay
# Processing Record508 of Set 10 | bulgan
# Processing Record509 of Set 10 | christchurch
# Processing Record511 of Set 11 | penzance
# Processing Record512 of Set 11 | libertador general san martin
# Processing Record513 of Set 11 | zhanaozen
# Processing Record514 of Set 11 | syamzha
# Processing Record515 of Set 11 | sur
# Processing Record516 of Set 11 | lugovoy
# Processing Record517 of Set 11 | te anau
# Processing Record518 of Set 11 | mirandela
# Processing Record519 of Set 11 | abalak
# Processing Record520 of Set 11 | stanger
# Processing Record521 of Set 11 | manokwari
# Processing Record522 of Set 11 | pemba
# Processing Record523 of Set 11 | ixtapa
# Processing Record524 of Set 11 | isangel
# Processing Record525 of Set 11 | uyuni
# Processing Record526 of Set 11 | valle de allende
# Processing Record527 of Set 11 | jurm
# Processing Record528 of Set 11 | jacareacanga
# Processing Record529 of Set 11 | balykshi
# Processing Record530 of Set 11 | victor harbor
# Processing Record531 of Set 11 | onega
# Processing Record532 of Set 11 | ubinskoye
# Processing Record533 of Set 11 | kirkwall
# Processing Record534 of Set 11 | vao
# Processing Record535 of Set 11 | nautla
# Processing Record536 of Set 11 | san rafael
# Processing Record537 of Set 11 | svirsk
# Processing Record538 of Set 11 | aswan
# Processing Record539 of Set 11 | victoria
# Processing Record540 of Set 11 | pandharpur
# Processing Record541 of Set 11 | la cruz
# Processing Record542 of Set 11 | lopatino
# Processing Record543 of Set 11 | kurilsk
# Processing Record544 of Set 11 | sisimiut
# Processing Record545 of Set 11 | bonthe
# Processing Record546 of Set 11 | dublin
# Processing Record547 of Set 11 | tsnori
# Processing Record548 of Set 11 | stamford
# Processing Record549 of Set 11 | volgodonsk
# Processing Record550 of Set 11 | dakar
# Processing Record551 of Set 11 | pisco
# Processing Record552 of Set 11 | severo-yeniseyskiy
# Processing Record553 of Set 11 | luderitz
# Processing Record554 of Set 11 | lavrentiya
# Processing Record555 of Set 11 | ancud
# Processing Record556 of Set 11 | pareora
# Processing Record557 of Set 11 | korla
# Processing Record558 of Set 11 | vilyuysk
# Processing Record559 of Set 11 | altay
# Processing Record560 of Set 11 | teguldet
# Processing Record562 of Set 12 | topolobampo
# Processing Record563 of Set 12 | broome
# Processing Record564 of Set 12 | aquiraz
# Processing Record565 of Set 12 | mpraeso
# Processing Record566 of Set 12 | ketchikan
# Processing Record567 of Set 12 | rosarito
# Processing Record568 of Set 12 | upata
# Processing Record569 of Set 12 | sisak
# Processing Record570 of Set 12 | itoman
# Processing Record571 of Set 12 | zhumadian
# Processing Record572 of Set 12 | buenaventura
# Processing Record573 of Set 12 | kuytun
# Processing Record574 of Set 12 | herat
# Processing Record575 of Set 12 | raudeberg
# Processing Record576 of Set 12 | ambilobe
# Processing Record577 of Set 12 | jatai
# Processing Record578 of Set 12 | berlevag
# Processing Record579 of Set 12 | hovd
# Processing Record580 of Set 12 | wawa
# Processing Record581 of Set 12 | inhambane
# Processing Record582 of Set 12 | danane
# Processing Record583 of Set 12 | samarai
# Processing Record584 of Set 12 | vyazemskiy
# Processing Record585 of Set 12 | hobyo
# Processing Record586 of Set 12 | pevek
# Processing Record587 of Set 12 | tombouctou
# Processing Record588 of Set 12 | yinchuan
# Processing Record589 of Set 12 | mangrol
# Processing Record590 of Set 12 | banda aceh
# Processing Record591 of Set 12 | hunza
# City not found. Skipping...
# Processing Record592 of Set 12 | yuzhne
# Processing Record593 of Set 12 | rocky mountain house
# Processing Record594 of Set 12 | vaitape
# Processing Record595 of Set 12 | smolensk
# Processing Record596 of Set 12 | harper
# Processing Record597 of Set 12 | zhuanghe
# Processing Record598 of Set 12 | port moresby
# Processing Record599 of Set 12 | waddan
# Processing Record600 of Set 12 | caidian
# Processing Record601 of Set 12 | nemuro
# Processing Record602 of Set 12 | carutapera
# Processing Record603 of Set 12 | dalen
# Processing Record604 of Set 12 | balkhash
# Processing Record605 of Set 12 | swellendam
# Processing Record606 of Set 12 | palmer
# Processing Record607 of Set 12 | george
# Processing Record608 of Set 12 | kerema
# Processing Record609 of Set 12 | yichang
# Processing Record610 of Set 12 | husavik
# Processing Record611 of Set 12 | alyangula
# Processing Record613 of Set 13 | zlotoryja
# Processing Record614 of Set 13 | altamont
# Processing Record615 of Set 13 | curup
# Processing Record616 of Set 13 | mabaruma
# Processing Record617 of Set 13 | nehe
# Processing Record618 of Set 13 | pithora
# Processing Record619 of Set 13 | flinders
# Processing Record620 of Set 13 | nabire
# Processing Record621 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record622 of Set 13 | porto velho
# Processing Record623 of Set 13 | rabo de peixe
# Processing Record624 of Set 13 | achisay
# City not found. Skipping...
# Processing Record625 of Set 13 | niltepec
# Processing Record626 of Set 13 | bakchar
# Processing Record627 of Set 13 | manaure
# Processing Record628 of Set 13 | beeville
# Processing Record629 of Set 13 | oriximina
# Processing Record630 of Set 13 | mbinga
# Processing Record631 of Set 13 | balsas
# Processing Record632 of Set 13 | coahuayana
# Processing Record633 of Set 13 | leh
# Processing Record634 of Set 13 | bima
# Processing Record635 of Set 13 | sierra vista
# Processing Record636 of Set 13 | montepuez
# Processing Record637 of Set 13 | joshimath
# Processing Record638 of Set 13 | tabou
# Processing Record639 of Set 13 | san joaquin
# Processing Record640 of Set 13 | koslan
# Processing Record641 of Set 13 | ambagarh chauki
# Processing Record642 of Set 13 | northam
# Processing Record643 of Set 13 | panaba
# Processing Record644 of Set 13 | ligayan
# Processing Record645 of Set 13 | verkhnevilyuysk
# Processing Record646 of Set 13 | srednekolymsk
# Processing Record647 of Set 13 | poso
# Processing Record648 of Set 13 | mapiripan
# Processing Record649 of Set 13 | ngama
# Processing Record650 of Set 13 | burica
# City not found. Skipping...
# Processing Record651 of Set 13 | carndonagh
# Processing Record652 of Set 13 | vasto
# Processing Record653 of Set 13 | kula
# Processing Record654 of Set 13 | santa catarina de tepehuanes
# Processing Record655 of Set 13 | bhopal
# Processing Record656 of Set 13 | zhezkazgan
# Processing Record657 of Set 13 | mikkeli
# Processing Record658 of Set 13 | ayagoz
# Processing Record659 of Set 13 | mogadishu
# Processing Record660 of Set 13 | bethanien
# Processing Record661 of Set 13 | riohacha
# Processing Record662 of Set 13 | san policarpo
# Processing Record664 of Set 14 | paramonga
# Processing Record665 of Set 14 | vangaindrano
# Processing Record666 of Set 14 | izumo
# Processing Record667 of Set 14 | eyl
# Processing Record668 of Set 14 | haimen
# Processing Record669 of Set 14 | santa cruz de la palma
# Processing Record670 of Set 14 | qandala
# Processing Record671 of Set 14 | dagua
# Processing Record672 of Set 14 | manta
# Processing Record673 of Set 14 | petauke
# Processing Record674 of Set 14 | hirado
# Processing Record675 of Set 14 | orlik
# Processing Record676 of Set 14 | pointe michel
# Processing Record677 of Set 14 | alta floresta
# Processing Record678 of Set 14 | tselinnoye
# Processing Record679 of Set 14 | wahran
# City not found. Skipping...
# Processing Record680 of Set 14 | petit goave
# Processing Record681 of Set 14 | jibuti
# Processing Record682 of Set 14 | marzuq
# Processing Record683 of Set 14 | suksun
# Processing Record684 of Set 14 | xanlar
# Processing Record685 of Set 14 | bonavista
# Processing Record686 of Set 14 | trincomalee
# Processing Record687 of Set 14 | ulaanbaatar
# Processing Record688 of Set 14 | rio blanco
# Processing Record689 of Set 14 | neryungri
# Processing Record690 of Set 14 | kodinsk
# Processing Record691 of Set 14 | ginda
# Processing Record692 of Set 14 | halalo
# City not found. Skipping...
# Processing Record693 of Set 14 | sharan
# Processing Record694 of Set 14 | grand forks
# Processing Record695 of Set 14 | jiujiang
# Processing Record696 of Set 14 | micheweni
# Processing Record697 of Set 14 | svinita
# Processing Record698 of Set 14 | tenancingo
# Processing Record699 of Set 14 | wilmington
# Processing Record700 of Set 14 | san matias
# Processing Record701 of Set 14 | uchaly
# Processing Record702 of Set 14 | thomasville
# Processing Record703 of Set 14 | mayo
# Processing Record704 of Set 14 | vestmanna
# Processing Record705 of Set 14 | lagoa
# Processing Record706 of Set 14 | ulladulla
# Processing Record707 of Set 14 | yendi
# Processing Record708 of Set 14 | quatre cocos
# Processing Record709 of Set 14 | khovu-aksy
# Processing Record710 of Set 14 | camacupa
# Processing Record711 of Set 14 | tabas
# Processing Record712 of Set 14 | severodvinsk
# Processing Record713 of Set 14 | jalu
# Processing Record715 of Set 15 | bluefields
# Processing Record716 of Set 15 | winnemucca
# Processing Record717 of Set 15 | ngunguru
# Processing Record718 of Set 15 | noumea
# Processing Record719 of Set 15 | ituni
# City not found. Skipping...
# Processing Record720 of Set 15 | tandil
# Processing Record721 of Set 15 | galesong
# Processing Record722 of Set 15 | suntar
# Processing Record723 of Set 15 | fairlie
# Processing Record724 of Set 15 | guiglo
# Processing Record725 of Set 15 | trairi
# Processing Record726 of Set 15 | tommot
# Processing Record727 of Set 15 | qaqortoq
# Processing Record728 of Set 15 | toliary
# City not found. Skipping...
# Processing Record729 of Set 15 | bilibino
# Processing Record730 of Set 15 | pechenga
# Processing Record731 of Set 15 | tezu
# Processing Record732 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record733 of Set 15 | mancheral
# Processing Record734 of Set 15 | kytlym
# City not found. Skipping...
# Processing Record735 of Set 15 | laguna
# Processing Record736 of Set 15 | phuket
# Processing Record737 of Set 15 | smithers
# Processing Record738 of Set 15 | tawau
# Processing Record739 of Set 15 | sorland
# Processing Record740 of Set 15 | sitarganj
# Processing Record741 of Set 15 | tayu
# Processing Record742 of Set 15 | nhulunbuy
# Processing Record743 of Set 15 | nalhati
# Processing Record744 of Set 15 | hay river
# Processing Record745 of Set 15 | teya
# Processing Record746 of Set 15 | emba
# Processing Record747 of Set 15 | zyryanka
# Processing Record748 of Set 15 | samfya
# Processing Record749 of Set 15 | kyabe
# Processing Record750 of Set 15 | likhoslavl
# Processing Record751 of Set 15 | lujan
# Processing Record752 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record753 of Set 15 | sorong
# Processing Record754 of Set 15 | vuktyl
# Processing Record755 of Set 15 | southbridge
# Processing Record756 of Set 15 | aksarka
# Processing Record757 of Set 15 | shubarshi
# Processing Record758 of Set 15 | nokaneng
# Processing Record759 of Set 15 | hwange
# Processing Record760 of Set 15 | garowe
# Processing Record761 of Set 15 | kumluca
# Processing Record762 of Set 15 | kostomuksha
# Processing Record763 of Set 15 | beringovskiy
# Processing Record764 of Set 15 | ario
# City not found. Skipping...
# Processing Record766 of Set 16 | turayf
# Processing Record767 of Set 16 | himatnagar
# Processing Record768 of Set 16 | turukhansk
# Processing Record769 of Set 16 | kirillov
# Processing Record770 of Set 16 | marcona
# City not found. Skipping...
# Processing Record771 of Set 16 | odder
# Processing Record772 of Set 16 | havoysund
# Processing Record773 of Set 16 | magadan
# Processing Record774 of Set 16 | praxedis guerrero
# Processing Record775 of Set 16 | baracoa
# Processing Record776 of Set 16 | abong mbang
# Processing Record777 of Set 16 | tiarei
# Processing Record778 of Set 16 | sattahip
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 710

# %%
# Convert the array of dictionaryies to a Pandas DataFrame.
city_data_df= pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Fangshan  39.6983  115.9925     66.06        96         100
# 1         Obigarm  38.7173   69.7088     60.13        25           0
# 2          Hobart -42.8794  147.3294     49.86        74          20
# 3       Saskylakh  71.9167  114.0833     33.57        98         100
# 4     Port-Gentil  -0.7193    8.7815     77.97        83          79
# 5      Butaritari   3.0707  172.7902     82.51        75           6
# 6         Bubaque  11.2833  -15.8333     82.22        76          99
# 7            Asau  46.4333   26.4000     45.95        78          84
# 8          Ouango   4.3133   22.5552     68.85        99         100
# 9  Ribeira Grande  38.5167  -28.7000     70.48        64         100
#
#    Wind Speed Country Current Description
# 0        6.60      CN          light rain
# 1        4.92      TJ           clear sky
# 2        1.99      AU          few clouds
# 3       10.87      RU     overcast clouds
# 4        9.08      GA       broken clouds
# 5       16.08      KI          light rain
# 6        7.85      GW     overcast clouds
# 7        6.76      RO       broken clouds
# 8        1.77      CF     overcast clouds
# 9        6.89      PT     overcast clouds

# %%
new_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df.reindex(columns=new_order)
city_data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Fangshan      CN  39.6983  115.9925     66.06        96
# 1              Obigarm      TJ  38.7173   69.7088     60.13        25
# 2               Hobart      AU -42.8794  147.3294     49.86        74
# 3            Saskylakh      RU  71.9167  114.0833     33.57        98
# 4          Port-Gentil      GA  -0.7193    8.7815     77.97        83
# ..                 ...     ...      ...       ...       ...       ...
# 705  Praxedis Guerrero      MX  31.3667 -106.0167     87.57        19
# 706            Baracoa      CU  20.3467  -74.4958     83.73        77
# 707        Abong Mbang      CM   3.9833   13.1833     67.42        99
# 708             Tiarei      PF -17.5333 -149.3333     84.22        76
# 709           Sattahip      TH  12.6664  100.9007     80.69        83
#
#      Cloudiness  Wind Speed Current Description
# 0           100        6.60          light rain
# 1             0        4.92           clear sky
# 2            20        1.99          few clouds
# 3           100       10.87     overcast clouds
# 4            79        9.08       broken clouds
# ..          ...         ...                 ...
# 705          98        6.96     overcast clouds
# 706         100        3.96     overcast clouds
# 707         100        1.14       moderate rain
# 708           2       16.71          light rain
# 709          40        6.91    scattered clouds
#
# [710 rows x 9 columns]

# %%
# Create teh output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
